# %% [markdown]
# # Secant Method

# %% [markdown]
# $f(x)=\cos(x+0.12\pi)-0.20$

# %% [markdown]
# Find a root in an interval using secant method

# %%
import math

def f(x):
    y = math.cos(x + 0.12 * math.pi) - 0.20
    return y

x = [i * 0.04  for i in range(0, 100 + 1)]
y = [f(i) for i in x]

# %% [markdown]
# $x_{n+2} = x_{n+1} - \frac{(x_{n+1}-x_n)f(x_{n+1})}{f(x_{n+1})-f(x_n)}$

# %%
xroot = []
yroot = []

x0 = 1
y0 = f(x0)
xroot.append(x0)
yroot.append(y0)

x1 = 2
y1 = f(x1)
xroot.append(x1)
yroot.append(y1)

i = 2
eps = 1E-6
dx = 10
print("iter root         f(root)")
while dx > eps and i < 20:
    x0 = xroot[i-2]
    x1 = xroot[i-1]
    if i == 2:
        print(f"{i-2:04d}", f"{x0:.6E}", f"{f(x0):+.6E}")
        print(f"{i-1:04d}", f"{x1:.6E}", f"{f(x1):+.6E}")
    
    x2 = x1 - (x1 - x0) * f(x1) / ( f(x1) - f(x0) )
    
    xroot.append(x2)
    dx = abs(f(x2))
    
    print(f"{i:04d}", f"{x2:.6E}", f"{f(x2):+.6E}")
    i += 1
# Out:
# iter root         f(root)
# 0000 1.000000E+00 -7.405751E-03
# 0001 2.000000E+00 -9.216583E-01
# 0002 9.918997E-01 +5.365273E-04
# 0003 9.924862E-01 -3.809963E-05
# 0004 9.924473E-01 +2.131312E-09

# %%
print("root =", xroot[-1])
print("f(root) =", f(xroot[-1]))
# Out:
# root = 0.992447285398529
# f(root) = 2.131312459852097e-09

# %%
yroot = [f(i) for i in xroot]

# %%
import matplotlib.pyplot as plt
plt.grid()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.plot(x, y, '-', xroot, yroot, 'r.', lw=2)
plt.show()

# %%
plt.grid()
plt.xlabel("iter")
plt.ylabel("f(x)")
plt.plot(yroot, 'r.-')
plt.show()

# %%
plt.grid()
plt.xlabel("iter")
plt.ylabel("x")
plt.plot(xroot, 'r.-')
plt.show()
