# %% [markdown]
# # Newton Raphson Method

# %% [markdown]
# $f(x)=\cos(x+0.12\pi)-0.20$

# %% [markdown]
# Find a root in an interval using newton-raphson method

# %%
import math

def f(x):
    y = math.cos(x + 0.12 * math.pi) - 0.20
    return y

x = [i * 0.04  for i in range(0, 100 + 1)]
y = [f(i) for i in x]

def df(x):
    dy = -math.sin(x + 0.12 * math.pi)
    return dy

# %% [markdown]
# $x_{n+1} = x_n - \frac{f(x_n)}{f'(x_n)}$

# %%
xroot = []
yroot = []

x0 = 1
y0 = f(x0)

xroot.append(x0)
yroot.append(y0)

i = 1
eps = 1E-6
dx = 10
print("iter root         f(root)")
while dx > eps and i < 20:
    x0 = xroot[i-1]
    if i == 1:
        print(f"{i-1:04d}", f"{x0:.6E}", f"{f(x0):+.6E}")
    
    x1 = x0 - f(x0) / df(x0)
    
    xroot.append(x1)
    dx = abs(f(x1))
    
    print(f"{i:04d}", f"{x1:.6E}", f"{f(x1):+.6E}")
    i += 1
# Out:
# iter root         f(root)
# 0000 1.000000E+00 -7.405751E-03
# 0001 9.924530E-01 -5.555154E-06
# 0002 9.924473E-01 -3.214512E-12

# %%
print("root =", xroot[-1])
print("f(root) =", f(xroot[-1]))
# Out:
# root = 0.9924472875770716
# f(root) = -3.2145119899240626e-12

# %%
yroot = [f(i) for i in xroot]

# %%
import matplotlib.pyplot as plt
plt.grid()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.plot(x, y, '-', xroot, yroot, 'r.', lw=2)
plt.show()

# %%
plt.grid()
plt.xlabel("iter")
plt.ylabel("f(x)")
plt.plot(yroot, 'r.-')
plt.show()

# %%
plt.grid()
plt.xlabel("iter")
plt.ylabel("x")
plt.plot(xroot, 'r.-')
plt.show()
